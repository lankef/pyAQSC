# %% [markdown]
# # Iteration test
# This file demonstrates how to initialize an Equilibrium object from leading order quantities and tests its accuracy.

# %%
# This file implements and tests recursion relations
import numpy as np
import timeit
import scipy.signal
from matplotlib import pyplot as plt
from numba import jit, njit, prange
from numba import complex128, int64    # import jit value types
from functools import lru_cache # import functools for caching
import warnings

# for importing parsed codes
import sys
sys.path.insert(1,'../python_source/MHD_parsed/')
sys.path.insert(1,'../python_source/')
from chiphifunc import *
from math_utilities import *
from chiphiepsfunc import *
from chiphifunc_test_suite import *
from equilibrium import *
debug_path = '../test_data_eduardo/'
# Out:
# /Users/lanke/anaconda3/envs/nae/lib/python3.10/site-packages/jax/_src/api_util.py:165: SyntaxWarning: Jitted function has static_argnums=(10, 11), but only accepts 11 positional arguments. This warning will be replaced by an error after 2022-08-20 at the earliest.
#   warnings.warn(f"Jitted function has {argnums_name}={argnums}, "

# %% [raw]
# # No B theta
# B_psi_coef_cp, B_theta_coef_cp, \
#     Delta_coef_cp, p_perp_coef_cp,\
#     X_coef_cp, Y_coef_cp, Z_coef_cp, \
#     iota_coef, dl_p,\
#     nfp, Xi_0, eta, \
#     B_denom_coef_c, B_alpha_coef, \
#     kap_p, tau_p = read_first_three_orders(
#         debug_path+'circ/',
#         R_array=[2,0,1,2,0.0001,0],
#         Z_array=[1,2,0,0.001]
#     )

# %% [raw]
# # No B theta
# B_psi_coef_cp, B_theta_coef_cp, \
#     Delta_coef_cp, p_perp_coef_cp,\
#     X_coef_cp, Y_coef_cp, Z_coef_cp, \
#     iota_coef, dl_p,\
#     nfp, Xi_0, eta, \
#     B_denom_coef_c, B_alpha_coef, \
#     kap_p, tau_p = read_first_three_orders(
#         debug_path+'5.2/',
#         R_array=[4,0,1,2,0.173,0,4,0.0168,0,6,0.00101,0],
#         Z_array=[3,2,0,0.159,4,0,0.0165,6,0,0.000987]
#     )
# B_theta_coef_cp = B_theta_coef_cp.zero_append().zero_append()

# %% [raw]
# B_psi_coef_cp, B_theta_coef_cp, \
#     Delta_coef_cp, p_perp_coef_cp,\
#     X_coef_cp, Y_coef_cp, Z_coef_cp, \
#     iota_coef, dl_p,\
#     nfp, Xi_0, eta, \
#     B_denom_coef_c, B_alpha_coef, \
#     kap_p, tau_p = read_first_three_orders(
#         debug_path+'5.3/',
#         R_array=[2,0,1,2,0.09,0],
#         Z_array=[1,2,0,-0.09]
#     )

# %%
# No B theta
B_psi_coef_cp, B_theta_coef_cp, \
    Delta_coef_cp, p_perp_coef_cp,\
    X_coef_cp, Y_coef_cp, Z_coef_cp, \
    iota_coef, dl_p,\
    nfp, Xi_0, eta, \
    B_denom_coef_c, B_alpha_coef, \
    kap_p, tau_p = read_first_three_orders(
        debug_path+'5.4/', 
        R_array=[5,0,1,4,0.17,0,8,0.018191838304685660487880483060508,0,12,0.001420200653346571223467620370684,0,16,0.000059148767213264540889769427245426,0],
        Z_array=[5,0,0,4,0,0.15464423020448464507481389773602,8,0,0.017913837381820285621358834760031,12,0,0.0014893730073718687394179749361456,16,0,0.00006923943338841940945208031088498],
        nfp_enabled=True
    )
B_theta_coef_cp = B_theta_coef_cp.zero_append()
# Out:
# Configuration has 4.0 field periods.
# iota -- list(np.loadtxt(path+outputs.dat)) [2.8634302, -2.5385231]
# Axis shape:

# %% [raw]
# B_psi_coef_cp, B_theta_coef_cp, \
#     Delta_coef_cp, p_perp_coef_cp,\
#     X_coef_cp, Y_coef_cp, Z_coef_cp, \
#     iota_coef, dl_p,\
#     nfp, Xi_0, eta, \
#     B_denom_coef_c, B_alpha_coef, \
#     kap_p, tau_p = read_first_three_orders(
#         debug_path+'5.5/',
#         R_array=[2,0,1,5,0.3,0],
#         Z_array=[2,0,0,5,0,0.3]
#     )

# %% [raw]
# # No B theta
# B_psi_coef_cp, B_theta_coef_cp, \
#     Delta_coef_cp, p_perp_coef_cp,\
#     X_coef_cp, Y_coef_cp, Z_coef_cp, \
#     iota_coef, dl_p,\
#     nfp, Xi_0, eta, \
#     B_denom_coef_c, B_alpha_coef, \
#     kap_p, tau_p = read_first_three_orders(
#         debug_path+'5.2/',
#         R_array=[4,0,1,2,0.173,0,4,0.0168,0,6,0.00101,0],
#         Z_array=[3,2,0,0.159,4,0,0.0165,6,0,0.000987]
#     )
# B_theta_coef_cp = B_theta_coef_cp.zero_append().zero_append()

# %% [markdown]
# ## Initializing an `Equilibrium`
# ### Required quantities and orders
# Unknowns:
#
# 1. X_coef_cp: 2
# 2. Y_coef_cp: 2
# 3. Z_coef_cp: 2
# 4. B_psi_coef_cp: 0
# 5. B_theta_coef_cp: 2
# 6. iota_coef: 0
# 7. Delta_coef_cp: 3
# 8. p_perp_coef_cp: 3
#
# Known constants:
# 1. B_denom_coef_c: 2
# 2. B_alpha_coef: 1
# 3. kap_p
# 4. dl_p
# 5. tau_p
# 6. eta

# %%
equilibrium = Equilibrium.from_known(
    X_coef_cp=X_coef_cp.mask(2),
    Y_coef_cp=Y_coef_cp.mask(2),
    Z_coef_cp=Z_coef_cp.mask(2),
    B_psi_coef_cp=B_psi_coef_cp.mask(0),
    B_theta_coef_cp=B_theta_coef_cp.mask(2),
    B_denom_coef_c=B_denom_coef_c.mask(2),
    B_alpha_coef=B_alpha_coef.mask(1),
    iota_coef=iota_coef.mask(0), 
    kap_p=kap_p, 
    dl_p=dl_p, 
    tau_p=tau_p,
    p_perp_coef_cp = ChiPhiEpsFunc.zeros_like(X_coef_cp.mask(2)), # no pressure or delta
    Delta_coef_cp = ChiPhiEpsFunc.zeros_like(X_coef_cp.mask(2)),
    magnetic_only=True
)

# %% [markdown]
# ## Iterate 2 orders using only the magentic equations

# %%
# %%time
equilibrium = iterate_2_magnetic_only(equilibrium,
    B_theta_nm1=ChiPhiFuncSpecial(0), B_theta_n=ChiPhiFuncSpecial(0),
    Yn0=0,
    B_psi_nm20=0,
    B_alpha_nb2=ChiPhiFuncSpecial(0),
    B_denom_nm1=ChiPhiFuncSpecial(0), B_denom_n=ChiPhiFuncSpecial(0),
    iota_nm2b2=ChiPhiFuncSpecial(0),
    max_freq=None,
    n_eval=6
    )
# Out:
# CPU times: user 3.53 s, sys: 380 ms, total: 3.91 s
# Wall time: 1.16 s

# %%
def test_iteration_speed():
    equilibrium.iterate_2_magnetic_only(
    B_theta_nm1=ChiPhiFuncSpecial(0), B_theta_n=ChiPhiFuncSpecial(0),
    Yn0=0,
    B_psi_nm20=0,
    B_alpha_nb2=ChiPhiFuncSpecial(0),
    B_denom_nm1=ChiPhiFuncSpecial(0), B_denom_n=ChiPhiFuncSpecial(0),
    iota_nm2b2=ChiPhiFuncSpecial(0),
    max_freq=None,
    n_eval=4
    )
    
# now lambda creation is jitted
import cProfile
import pstats
profile = cProfile.Profile()
profile.runcall(test_iteration_speed)
ps = pstats.Stats(profile)
ps.print_stats()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 17
#      15 import pstats
#      16 profile = cProfile.Profile()
# ---> 17 profile.runcall(test_iteration_speed)
#      18 ps = pstats.Stats(profile)
#      19 ps.print_stats()
#
# File ~/anaconda3/envs/nae/lib/python3.10/cProfile.py:109, in Profile.runcall(self, func, *args, **kw)
#     107 self.enable()
#     108 try:
# --> 109     return func(*args, **kw)
#     110 finally:
#     111     self.disable()
#
# Cell In[5], line 2, in test_iteration_speed()
#       1 def test_iteration_speed():
# ----> 2     equilibrium.iterate_2_magnetic_only(
#       3     B_theta_nm1=ChiPhiFuncSpecial(0), B_theta_n=ChiPhiFuncSpecial(0),
#       4     Yn0=0,
#       5     B_psi_nm20=0,
#       6     B_alpha_nb2=ChiPhiFuncSpecial(0),
#       7     B_denom_nm1=ChiPhiFuncSpecial(0), B_denom_n=ChiPhiFuncSpecial(0),
#       8     iota_nm2b2=ChiPhiFuncSpecial(0),
#       9     max_freq=None,
#      10     n_eval=4
#      11     )
#
# AttributeError: 'Equilibrium' object has no attribute 'iterate_2_magnetic_only'

# %% [markdown]
# ## Accessing data and checking accuracy

# %%
X3_from_equilibrium = equilibrium.unknown['X_coef_cp'][3]
Y3_from_equilibrium = equilibrium.unknown['Y_coef_cp'][3]
print('X_3')
X3_from_equilibrium.display()
print('Y_3')
Y3_from_equilibrium.display()
# Out:
# X_3
# Y_3

# %%
X3_benchmark = X_coef_cp[3]
Y3_benchmark = Y_coef_cp[3]
print('X_3 accuracy')
compare_chiphifunc(X3_from_equilibrium,X3_benchmark)
print('Y_3 accuracy')
compare_chiphifunc(Y3_from_equilibrium.filter(50),Y3_benchmark, simple_mode=False)
# Out:
# X_3 accuracy
# Difference
# fractional errors b/w data and general formula
# Error type:     Fractional      Total
# Avg:            9.25e-05        7.824e-04
# Worst:          4.667e-04       6.816e-03
# Std             8.424e-05       1.071e-03
# Total imaginary component
# 0.0
#
# Y_3 accuracy
# A
# B
# Difference
# fractional errors b/w data and general formula
# Error type:     Fractional      Total
# Avg:            2.283e+08       1.540e+09
# Worst:          8.284e+08       6.437e+09
# Std             2.062e+08       1.544e+09
# Total imaginary component
# 0.0

# %%
# (xk+yt) is satisfied, but k or t aren't individually satisfied??
# E6 was tested.
J, Cb, Ck, Ct, I, II, III =\
    equilibrium.check_governing_equations(2)
test_filter_freq = 50
print('J LHS-RHS')
J.filter(test_filter_freq).display_content()
print('Cb LHS-RHS')
Cb.filter(test_filter_freq).display_content()
print('Ck LHS-RHS')
Ck.filter(test_filter_freq).display_content()
print('Ct LHS-RHS')
Ct.filter(test_filter_freq).display_content()
# Out:
# J LHS-RHS
# Cb LHS-RHS
# Ck LHS-RHS
# Ct LHS-RHS
